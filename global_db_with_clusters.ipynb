# %%
import pandas as pd
import numpy as np

# %%
global_db_with_clusters = pd.read_csv('/data/elugos/global_db_with_clusters.csv')

# %%
for cluster_id, group in global_db_with_clusters.groupby('cluster'):
    print(f"\n🟣 Cluster {cluster_id} ({len(group)} events)")
    print(group['EventCode'].value_counts())
    print(group['state'].value_counts())
    print()
# Out:
# 🟣 Cluster -1 (172 events)
# EventCode
# 10.0_10_1       38
# 20.0_20_2       17
# 40.0_40_4       16
# 43.0_43_4       15
# 51.0_51_5       13
# 90.0_90_9       10
# 111.0_111_11     9
# 42.0_42_4        8
# 112.0_112_11     8
# 13.0_13_1        7
# 190.0_190_19     6
# 193.0_193_19     6
# 173.0_173_17     5
# 12.0_12_1        4
# 11.0_11_1        3
# 17.0_17_1        2
# 141.0_141_14     2
# 14.0_14_1        2
# 18.0_18_1        1
# Name: count, dtype: int64
# state
# NY    92
# FL    47
# CO    31
# CA     2
# Name: count, dtype: int64
#
# 🟣 Cluster 0 (5 events)
# EventCode
# 173.0_173_17    5
# Name: count, dtype: int64
# state
# CO    5
# Name: count, dtype: int64
#
# 🟣 Cluster 1 (7 events)
# EventCode
# 173.0_173_17    3
# 190.0_190_19    2
# 20.0_20_2       1
# 15.0_15_1       1
# Name: count, dtype: int64
# state
# CO    4
# NY    2
# FL    1
# Name: count, dtype: int64
#
# 🟣 Cluster 2 (28 events)
# EventCode
# 10.0_10_1       7
# 40.0_40_4       6
# 190.0_190_19    3
# ...

# %%
global_db_with_clusters.head()
# Out:
#    GlobalEventID      date     EventCode state  \
# 0     1246626272  20250529     13.0_13_1    CO
# 1     1246714485  20250529     10.0_10_1    CO
# 2     1246728911  20250529  173.0_173_17    CO
# 3     1246756951  20250529     20.0_20_2    CO
# 4     1246759627  20250529     51.0_51_5    CO
#
#                                                title  cluster
# 0  Colorado toddler hospitalized with measles, st...       -1
# 1  How protests over George Floyd’s death led Col...       -1
# 2      Does Loveland Have a Casino on the "Downlow?"        0
# 3               High court reverses oil train ruling       -1
# 4  Supreme Court endorses narrow environmental re...       -1
