# %%
import networkx as nx
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import csv
import ast
import re

# %%
pd.reset_option('all')
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# /Users/emilylugos/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# /Users/emilylugos/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
# ...

# %%
pd.set_option('expand_frame_repr', True)
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
d_20250529 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250529.export_triples_sbert.csv')
d_20250530 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250530.export_triples_sbert.csv')
d_20250531 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250531.export_triples_sbert.csv')
d_20250601 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250601.export_triples_sbert.csv')
d_20250602 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250602.export_triples_sbert.csv')
d_20250603 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250603.export_triples_sbert.csv')
d_20250604 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250604.export_triples_sbert.csv')
d_20250605 = pd.read_csv('/Users/emilylugos/Desktop/Desktop - Emily’s MacBook Pro/summer_2025/research/HSMS_LUGOS/data/triples_CO_sbert/goose_20250605.export_triples_sbert.csv')

# %%
f_20250529 = d_20250529.loc[d_20250529['source_index'] == 0]
f_20250530 = d_20250530.loc[d_20250530['source_index'] == 0]
f_20250531 = d_20250531.loc[d_20250531['source_index'] == 0]
f_20250601 = d_20250601.loc[d_20250601['source_index'] == 0]
f_20250602 = d_20250602.loc[d_20250602['source_index'] == 0]
f_20250603 = d_20250603.loc[d_20250603['source_index'] == 0]
f_20250604 = d_20250604.loc[d_20250604['source_index'] == 0]
f_20250605 = d_20250605.loc[d_20250605['source_index'] == 0]

# %%
f_20250529.head()
# Out:
#       GlobalEventID      date  source_index               subject  \
# 141      1246616308  20250529             0           Authorities
# 406      1246616308  20250529             0       Ezra Bald Eagle
# 709      1246616308  20250529             0          Mariah Cross
# 1174     1246616308  20250529             0  UNET drug task force
# 1588     1246616308  20250529             0          distribution
#
#                 relation                   object  \
# 141            have made  major drug bust seizing
# 406       are now facing         multiple charges
# 709       are now facing                  charges
# 1174  stopped vehicle On                  Tuesday
# 1588               is in               Rapid City
#
#                                            sbert_text  \
# 141     Authorities have made major drug bust seizing
# 406   Ezra Bald Eagle are now facing multiple charges
# 709               Mariah Cross are now facing charges
# ...

# %%
def dedupe_relation_longest_object(df: pd.DataFrame,
                                  subject_col: str = "subject",
                                  relation_col: str = "relation") -> pd.DataFrame:    
 # Make sure object is string, measure length
    df = df.copy()
    df["_len"] = df[relation_col].fillna("").astype(str).str.len()

    # For each subject, keep row with longest object
    idx = df.groupby(subject_col)["_len"].idxmax()

    result = df.loc[idx].drop(columns=["_len"]).reset_index(drop=True)
    return result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5_/qm_vvwjs1rdch76vs4mv5j140000gn/T/ipykernel_13832/3034024923.py in <module>
# ----> 1 def dedupe_relation_longest_object(df: pd.DataFrame,
#       2                                   subject_col: str = "subject",
#       3                                   relation_col: str = "relation") -> pd.DataFrame:
#       4  # Make sure object is string, measure length
#       5     df = df.copy()
#
# NameError: name 'pd' is not defined

# %%
r_20250529 = dedupe_subject_longest_object(f_20250529)
r_20250530 = dedupe_subject_longest_object(f_20250530)
r_20250531 = dedupe_subject_longest_object(f_20250531)
r_20250601 = dedupe_subject_longest_object(f_20250601)
r_20250602 = dedupe_subject_longest_object(f_20250602)
r_20250603 = dedupe_subject_longest_object(f_20250603)
r_20250604 = dedupe_subject_longest_object(f_20250604)
r_20250605 = dedupe_subject_longest_object(f_20250605)

# %%
# semantic similarity 
# sentence berg
# less then ten
# use graphic structure with triples
# subject nodes
# relation are paths
# object are also nodes
# get a few of them and start graphing
# use sbert to compare semantic similarity
# get the distances and how are we going to condense
# an avg of all the triples from  one doc to the other
# http://sbert.net/ miniLM
# pairwise triple to triple semantic similarty
# next step is agrerating at the text level

# %%
r_20250531
# Out:
#     source_index                        subject        relation  \
# 0              0                           UCLA           is in
# 1              0                          world              in
# 2              0                       articles     may require
# 3              0                      more UCLA           is in
# 4              0                 Gregory Pierce  co-director of
# 5              0                    populations             are
# 6              0         supporting populations             are
# 7              0                             We           think
# 8              0                           they            said
# 9              0            high transit riders       live near
# 10             0                 transit riders       live near
# 11             0                             it           seems
# 12             0                   Second phase  kick off after
# 13             0                          phase  kick off after
# ...

# %%
#generate triples and put them into a file
#csv
