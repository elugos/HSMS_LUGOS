# %%
import networkx as nx
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import ast
import re

import urllib.request as urlrequest
from collections import Counter
from goose3 import Goose
from goose3.network import NetworkError
from bertopic import BERTopic
from scipy.cluster import hierarchy as sch
from sklearn.feature_extraction.text import CountVectorizer
from urllib.parse import urlparse
from scipy.spatial.distance import pdist, squareform
import umap
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import cdist
import torch
from collections import defaultdict

# %%
l_20140524_CA = pd.read_csv('d_20140524_CA.csv')
l_20160612_FL = pd.read_csv('d_20160612_FL.csv')
l_20170812_VA = pd.read_csv('d_20170812_VA.csv')
l_20171031_NY = pd.read_csv('d_20171031_NY.csv')
l_20250602_CO = pd.read_csv('d_20250602_CO.csv')

# %%
hurtlex_df = pd.read_csv("hurtlex_EN.tsv", sep="\t", header=None, comment="#")
hurtlex_df.columns = ["id", "pos", "category", "stereotype", "lemma", "level"]

# Create dictionaries to map lemma -> category and lemma -> level
lemma_to_category = defaultdict(list)
lemma_to_level = defaultdict(list)

for _, row in hurtlex_df.iterrows():
    lemma = row["lemma"].lower()
    lemma_to_category[lemma].append(row["category"])
    lemma_to_level[lemma].append(row["level"])

# Function to count both category and level matches
  
)

# %%
l_20140524_CA
# Out:
#      GlobalEventID      date  Year  IsRootEvent  EventCode  EventBaseCode  \
# 0        298548627  20140517  2014            1         12             12
# 1        298551064  20140524  2014            1        173            173
# 2        298551970  20140524  2014            1        193            193
# 3        298554304  20140524  2014            1        190            190
# 4        298556473  20140524  2014            1        190            190
# ..             ...       ...   ...          ...        ...            ...
# 129      298635186  20140524  2014            0         10             10
# 130      298636264  20140524  2014            1         10             10
# 131      298637362  20140524  2014            1        193            193
# 132      298637364  20140524  2014            1        193            193
# 133      298637367  20140524  2014            1        193            193
#
#      EventRootCode  QuadClass  GoldsteinScale  NumMentions  ...  \
# 0                1          1            -0.4            2  ...
# 1               17          4            -5.0            3  ...
# 2               19          4           -10.0            6  ...
# 3               19          4           -10.0           46  ...
# 4               19          4           -10.0          116  ...
# ..             ...        ...             ...          ...  ...
# 129              1          1             0.0           20  ...
# 130              1          1             0.0            6  ...
# 131             19          4           -10.0           12  ...
# 132             19          4           -10.0            6  ...
# 133             19          4           -10.0            2  ...
#
#      ActionGeo_FeatureID  DATEADDED  \
# 0                     CA   20140524
# 1                     CA   20140524
# 2                     CA   20140524
# 3                     CA   20140524
# 4                     CA   20140524
# ..                   ...        ...
# 129                   CA   20140524
# 130                   CA   20140524
# 131                   CA   20140524
# 132                   CA   20140524
# 133                   CA   20140524
#
#                                              SOURCEURL              domain  \
# 0    http://www.cbsnews.com/news/elliot-rodger-cali...     www.cbsnews.com
# 1    http://news.yahoo.com/farmers-death-still-myst...      news.yahoo.com
# 2    http://www.thesundaytimes.co.uk/sto/news/irela...    www.thetimes.com
# 3    http://www.military.com/daily-news/2014/05/22/...    www.military.com
# 4    http://www.dw.de/california-gunman-was-hollywo...          www.dw.com
# ..                                                 ...                 ...
# 129  http://www.odt.co.nz/news/world/303498/six-kil...       www.odt.co.nz
# 130  http://time.com/112292/states-running-out-of-w...            time.com
# 131  http://www.thestar.com.my/News/World/2014/05/2...  www.thestar.com.my
# 132  http://www.reuters.com/article/2014/05/25/us-u...     web.archive.org
# 133  http://www.reuters.com/article/2014/05/25/us-u...     web.archive.org
#
#        target                                              title  \
# 0     cbsnews  Shooting spree suspect son of longtime Hollywo...
# 1        news  Yahoo News: Latest and Breaking News, Headline...
# 2    thetimes                   Latest news & breaking headlines
# 3    military                                Military Daily News
# 4          dw   US gunman 'was director's son' – DW – 05/25/2014
# ..        ...                                                ...
# 129       odt          'Madman' killer stabs three, shoots three
# 130      time            These 7 States Are Running Out of Water
# 131   thestar  Suspect in California shootings apparently kil...
# 132       web  Suspect in California shootings apparently kil...
# 133       web  Suspect in California shootings apparently kil...
#
#                                                   text  \
# 0    Elliot Rodger, the suspect in Friday's deadly ...
# 1    \n• None A tiny California city prone to tsuna...
# 2                                                  NaN
# 3                                                  NaN
# 4    A Hollywood director says he believes his son ...
# ..                                                 ...
# 129  A gunman described as severely mentally distur...
# 130  This post is in partnership with 24/7Wall Stre...
# 131  (Reuters) - The suspected gunman in the Isla V...
# 132  The suspected gunman drove through Isla Vista ...
# 133  The suspected gunman drove through Isla Vista ...
#
#                                            description  \
# 0    A life of "sadness, anger and hatred," accordi...
# 1    The latest news and headlines from Yahoo News....
# 2    The latest breaking UK, US, world, business an...
# 3    Daily updates of everything that you need know...
# 4    A Hollywood director says he believes his son ...
# ..                                                 ...
# 129  A gunman described as severely mentally distur...
# 130  This post is in partnership with 24/7Wall Stre...
# 131  (Reuters) - The suspected gunman in the Isla V...
# 132                                                NaN
# 133                                                NaN
#
#                                hurtlex_category_counts  \
# 0    {'asm': 2, 'cds': 6, 'qas': 2, 'svp': 1, 'pa': 1}
# 1                                  {'cds': 7, 'ps': 2}
# 2                                                   {}
# 3                                                   {}
# 4    {'cds': 20, 'asm': 3, 'pa': 2, 'om': 1, 're': ...
# ..                                                 ...
# 129  {'cds': 18, 're': 4, 'asm': 8, 'ps': 2, 'dmc':...
# 130  {'re': 12, 'om': 1, 'cds': 6, 'qas': 2, 'ps': ...
# 131            {'asm': 2, 'ps': 2, 'dmc': 1, 'cds': 5}
# 132                      {'ps': 2, 'dmc': 1, 'cds': 5}
# 133                      {'ps': 2, 'dmc': 1, 'cds': 5}
#
#                      hurtlex_level_counts
# 0     {'conservative': 6, 'inclusive': 6}
# 1     {'inclusive': 7, 'conservative': 2}
# 2                                      {}
# 3                                      {}
# 4    {'inclusive': 22, 'conservative': 9}
# ..                                    ...
# 129  {'conservative': 8, 'inclusive': 26}
# 130  {'inclusive': 23, 'conservative': 3}
# 131   {'inclusive': 7, 'conservative': 3}
# 132   {'inclusive': 5, 'conservative': 3}
# 133   {'inclusive': 5, 'conservative': 3}
#
# [134 rows x 31 columns]
