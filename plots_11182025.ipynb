# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import networkx as nx
from sklearn.manifold import SpectralEmbedding
# import plotly.graph_objects as go
from typing import Set, Dict, Any, List, Tuple
from scipy import sparse
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from typing import Union, Optional
import plotly.express as px
import psutil
from sklearn.manifold import TSNE
import inspect
import re
import json
from sklearn.metrics import pairwise_distances
from pathlib import Path
from sentence_transformers import SentenceTransformer
from typing import Iterable, Optional
import plotly.graph_objects as go
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from sklearn.decomposition import PCA
from pathlib import Path

# %%
cameo_codes = {
    "MAKE PUBLIC STATEMENT": "1",
    "APPEAL": "2",
    "EXPRESS INTENT TO COOPERATE": "3",
    "CONSULT": "4",
    "ENGAGE IN DIPLOMATIC COOPERATION": "5",
    "ENGAGE IN MATERIAL COOPERATION": "6",
    "PROVIDE AID": "7",
    "YIELD": "8",
    "INVESTIGATE": "9",
    "DEMAND": "10",
    "DISAPPROVE": "11",
    "REJECT": "12",
    "THREATEN": "13",
    "PROTEST": "14",
    "EXHIBIT FORCE POSTURE": "15",
    "COERCE": "16",
    "ASSAULT": "17",
    "FIGHT": "19",
    "USE UNCONVENTIONAL MASS VIOLENCE": "20",
}

# %%
global_db = pd.read_csv('/data/elugos/global_db_111125.csv')

# %%
# --- Define CSV paths (SBERT_CO embeddings) ---
sbert_20250529 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250529.export_goosed_triples_sbert.csv'))
sbert_20250530 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250530.export_goosed_triples_sbert.csv'))
sbert_20250531 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250531.export_goosed_triples_sbert.csv'))
sbert_20250601 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250601.export_goosed_triples_sbert.csv'))
sbert_20250602 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250602.export_goosed_triples_sbert.csv'))
sbert_20250603 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250603.export_goosed_triples_sbert.csv'))
sbert_20250604 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250604.export_goosed_triples_sbert.csv'))
sbert_20250605 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250605.export_goosed_triples_sbert.csv'))
sbert_20250606 = pd.read_csv(Path('/data/elugos/titlesbert_CO/20250606.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_CO = pd.concat(
    [
        sbert_20250529,
        sbert_20250530,
        sbert_20250531,
        sbert_20250601,
        sbert_20250602,
        sbert_20250603,
        sbert_20250604,
        sbert_20250605,
        sbert_20250606,
    ],
    ignore_index=True
)

# %%
sbert_20140521 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140521.export_goosed_triples_sbert.csv'))
sbert_20140522 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140522.export_goosed_triples_sbert.csv'))
sbert_20140523 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140523.export_goosed_triples_sbert.csv'))
sbert_20140524 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140524.export_goosed_triples_sbert.csv'))
sbert_20140525 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140525.export_goosed_triples_sbert.csv'))
sbert_20140526 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140526.export_goosed_triples_sbert.csv'))
sbert_20140527 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140527.export_goosed_triples_sbert.csv'))
sbert_20140528 = pd.read_csv(Path('/data/elugos/titlesbert_CA/20140528.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_CA = pd.concat(
    [
        sbert_20140521,
        sbert_20140522,
        sbert_20140523,
        sbert_20140524,
        sbert_20140525,
        sbert_20140526,
        sbert_20140527,
        sbert_20140528,
    ],
    ignore_index=True
)

# %%
# --- Define CSV paths (SBERT_VA embeddings) ---
sbert_20170808 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170808.export_goosed_triples_sbert.csv'))
sbert_20170809 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170809.export_goosed_triples_sbert.csv'))
sbert_20170810 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170810.export_goosed_triples_sbert.csv'))
sbert_20170811 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170811.export_goosed_triples_sbert.csv'))
sbert_20170813 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170813.export_goosed_triples_sbert.csv'))
sbert_20170814 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170814.export_goosed_triples_sbert.csv'))
sbert_20170815 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170815.export_goosed_triples_sbert.csv'))
sbert_20170816 = pd.read_csv(Path('/data/elugos/titlesbert_VA/20170816.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_VA = pd.concat(
    [
        sbert_20170808,
        sbert_20170809,
        sbert_20170810,
        sbert_20170811,
        sbert_20170813,
        sbert_20170814,
        sbert_20170815,
        sbert_20170816,
    ],
    ignore_index=True
)

# %%
s_matrix
# Out:
#       node_id         x         y        x2        x3        x4        x5  \
# 0           0  0.000402 -0.000173  0.000414 -0.000260  0.000074  0.000310
# 1           1 -0.000174  0.000990  0.000021 -0.000478 -0.000407  0.000209
# 2           2  0.000033  0.000410  0.000082 -0.000992 -0.000217 -0.000077
# 3           3 -0.000351  0.000946  0.001247  0.000412  0.000326  0.000829
# 4           4 -0.000261  0.000170 -0.000473 -0.000511  0.000924  0.000441
# ...       ...       ...       ...       ...       ...       ...       ...
# 1782     1782  0.002523 -0.000845 -0.001079 -0.000092 -0.000781 -0.000019
# 1783     1783  0.000347 -0.000267  0.000371 -0.000634 -0.000006 -0.000178
# 1784     1784 -0.000688 -0.000118 -0.000052  0.000778 -0.000416  0.000242
# 1785     1785  0.000606  0.000841  0.000504 -0.000663  0.000229  0.000485
# 1786     1786 -0.000077  0.001007  0.000434  0.000345 -0.000268  0.000168
#
#             x6        x7        x8  ...       x31       x32       x33  \
# 0     0.000201 -0.000198  0.000061  ... -0.000602  0.000719 -0.000591
# 1    -0.000527  0.000396 -0.000898  ... -0.000291  0.000350  0.000591
# 2    -0.000647 -0.000261 -0.000613  ... -0.001230 -0.000980  0.000750
# 3    -0.000064 -0.000377  0.000393  ...  0.000603  0.000230  0.000436
# 4    -0.000059  0.000254 -0.000083  ... -0.000039 -0.000378 -0.000576
# ...        ...       ...       ...  ...       ...       ...       ...
# 1782  0.000582  0.001572 -0.001617  ...  0.000315 -0.000504  0.000480
# 1783  0.000870 -0.000038  0.000282  ...  0.000459  0.000568  0.000802
# 1784 -0.000419 -0.000602  0.000308  ...  0.000514 -0.000010  0.000081
# 1785 -0.000456 -0.000748 -0.000109  ...  0.000056 -0.000097 -0.000287
# 1786 -0.000287 -0.000777  0.000637  ...  0.000291 -0.000465  0.000252
#
#            x34       x35       x36       x37       x38       x39  \
# 0    -0.000025  0.000119 -0.000028 -0.000563 -0.000654  0.000462
# 1    -0.000159 -0.000049  0.000999  0.000280 -0.000111 -0.000683
# 2    -0.000126 -0.000754 -0.000466  0.000586  0.000522 -0.000484
# 3     0.000807 -0.000349 -0.000507  0.000566 -0.000400  0.000320
# 4    -0.000075 -0.000396 -0.000376 -0.000083  0.000471  0.000440
# ...        ...       ...       ...       ...       ...       ...
# 1782 -0.000020  0.000193 -0.000325  0.000571 -0.000314  0.000039
# 1783  0.000266 -0.000436 -0.000449  0.000213  0.000100  0.000685
# 1784  0.000544  0.000166  0.000537  0.000039  0.000067  0.000380
# 1785  0.000002  0.000470  0.000522 -0.000627 -0.000128 -0.000506
# 1786 -0.000114 -0.000060  0.000332  0.000008  0.000014  0.000697
#
#       GlobalEventID
# 0         298143273
# 1         298119883
# 2         298198975
# 3         298240156
# 4         298193098
# ...             ...
# 1782      299078979
# 1783      299037286
# 1784      299055568
# 1785      298999098
# 1786      298996848
#
# [1787 rows x 42 columns]

# %%
sbert_20171027 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171027.export_goosed_triples_sbert.csv'))
sbert_20171028 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171028.export_goosed_triples_sbert.csv'))
sbert_20171029 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171029.export_goosed_triples_sbert.csv'))
sbert_20171030 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171030.export_goosed_triples_sbert.csv'))
sbert_20171031 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171031.export_goosed_triples_sbert.csv'))
sbert_20171101 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171101.export_goosed_triples_sbert.csv'))
sbert_20171102 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171102.export_goosed_triples_sbert.csv'))
sbert_20171103 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171103.export_goosed_triples_sbert.csv'))
sbert_20171104 = pd.read_csv(Path('/data/elugos/titlesbert_NY/20171104.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_NY = pd.concat(
    [
        sbert_20171027,
        sbert_20171028,
        sbert_20171029,
        sbert_20171030,
        sbert_20171031,
        sbert_20171101,
        sbert_20171102,
        sbert_20171103,
        sbert_20171104,
    ],
    ignore_index=True
)

# %%
sbert_20160608 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160608.export_goosed_triples_sbert.csv'))
sbert_20160609 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160609.export_goosed_triples_sbert.csv'))
sbert_20160610 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160610.export_goosed_triples_sbert.csv'))
sbert_20160611 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160611.export_goosed_triples_sbert.csv'))
sbert_20160613 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160613.export_goosed_triples_sbert.csv'))
sbert_20160614 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160614.export_goosed_triples_sbert.csv'))
sbert_20160615 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160615.export_goosed_triples_sbert.csv'))
sbert_20160616 = pd.read_csv(Path('/data/elugos/titlesbert_FL/20160616.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_FL = pd.concat(
    [
        sbert_20160608,
        sbert_20160609,
        sbert_20160610,
        sbert_20160611,
        sbert_20160613,
        sbert_20160614,
        sbert_20160615,
        sbert_20160616,
    ],
    ignore_index=True
)

# %%
# --- Define CSV paths (SBERT_201908 embeddings) ---
sbert_20190821 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190821.export_goosed_triples_sbert.csv'))
sbert_20190822 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190822.export_goosed_triples_sbert.csv'))
sbert_20190823 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190823.export_goosed_triples_sbert.csv'))
sbert_20190824 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190824.export_goosed_triples_sbert.csv'))
sbert_20190825 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190825.export_goosed_triples_sbert.csv'))
sbert_20190826 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190826.export_goosed_triples_sbert.csv'))
sbert_20190827 = pd.read_csv(Path('/data/elugos/titlesbert_201908/20190827.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_201908 = pd.concat(
    [
        sbert_20190821,
        sbert_20190822,
        sbert_20190823,
        sbert_20190824,
        sbert_20190825,
        sbert_20190826,
        sbert_20190827,
    ],
    ignore_index=True
)

# %%
sbert_20200522 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200522.export_goosed_triples_sbert.csv'))
sbert_20200523 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200523.export_goosed_triples_sbert.csv'))
sbert_20200524 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200524.export_goosed_triples_sbert.csv'))
sbert_20200525 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200525.export_goosed_triples_sbert.csv'))
sbert_20200526 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200526.export_goosed_triples_sbert.csv'))
sbert_20200527 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200527.export_goosed_triples_sbert.csv'))
sbert_20200528 = pd.read_csv(Path('/data/elugos/titlesbert_202005/20200528.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202005 = pd.concat(
    [
        sbert_20200522,
        sbert_20200523,
        sbert_20200524,
        sbert_20200525,
        sbert_20200526,
        sbert_20200527,
        sbert_20200528,
    ],
    ignore_index=True
)

# %%
sbert_20240414 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240414.export_goosed_triples_sbert.csv'))
sbert_20240415 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240415.export_goosed_triples_sbert.csv'))
sbert_20240416 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240416.export_goosed_triples_sbert.csv'))
sbert_20240417 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240417.export_goosed_triples_sbert.csv'))
sbert_20240418 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240418.export_goosed_triples_sbert.csv'))
sbert_20240419 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240419.export_goosed_triples_sbert.csv'))
sbert_20240420 = pd.read_csv(Path('/data/elugos/titlesbert_202404/20240420.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202404 = pd.concat(
    [
        sbert_20240414,
        sbert_20240415,
        sbert_20240416,
        sbert_20240417,
        sbert_20240418,
        sbert_20240419,
        sbert_20240420,
    ],
    ignore_index=True
)

# %%
# --- Define CSV paths (SBERT_202412 embeddings) ---
sbert_20241201 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241201.export_goosed_triples_sbert.csv'))
sbert_20241202 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241202.export_goosed_triples_sbert.csv'))
sbert_20241203 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241203.export_goosed_triples_sbert.csv'))
sbert_20241204 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241204.export_goosed_triples_sbert.csv'))
sbert_20241205 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241205.export_goosed_triples_sbert.csv'))
sbert_20241206 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241206.export_goosed_triples_sbert.csv'))
sbert_20241207 = pd.read_csv(Path('/data/elugos/titlesbert_202412/20241207.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202412 = pd.concat(
    [
        sbert_20241201,
        sbert_20241202,
        sbert_20241203,
        sbert_20241204,
        sbert_20241205,
        sbert_20241206,
        sbert_20241207,
    ],
    ignore_index=True
)

# %%
sbert_20250104 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250104.export_goosed_triples_sbert.csv'))
sbert_20250105 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250105.export_goosed_triples_sbert.csv'))
sbert_20250106 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250106.export_goosed_triples_sbert.csv'))
sbert_20250107 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250107.export_goosed_triples_sbert.csv'))
sbert_20250108 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250108.export_goosed_triples_sbert.csv'))
sbert_20250109 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250109.export_goosed_triples_sbert.csv'))
sbert_20250110 = pd.read_csv(Path('/data/elugos/titlesbert_202501/20250110.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202501 = pd.concat(
    [
        sbert_20250104,
        sbert_20250105,
        sbert_20250106,
        sbert_20250107,
        sbert_20250108,
        sbert_20250109,
        sbert_20250110,
    ],
    ignore_index=True
)

# %%
sbert_20251015 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251015.export_goosed_triples_sbert.csv'))
sbert_20251016 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251016.export_goosed_triples_sbert.csv'))
sbert_20251017 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251017.export_goosed_triples_sbert.csv'))
sbert_20251018 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251018.export_goosed_triples_sbert.csv'))
sbert_20251019 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251019.export_goosed_triples_sbert.csv'))
sbert_20251020 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251020.export_goosed_triples_sbert.csv'))
sbert_20251021 = pd.read_csv(Path('/data/elugos/titlesbert_202510/20251021.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202510 = pd.concat(
    [
        sbert_20251015,
        sbert_20251016,
        sbert_20251017,
        sbert_20251018,
        sbert_20251019,
        sbert_20251020,
        sbert_20251021,
    ],
    ignore_index=True
)

# %%
sbert_20240924 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240924.export_goosed_triples_sbert.csv'))
sbert_20240925 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240925.export_goosed_triples_sbert.csv'))
sbert_20240926 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240926.export_goosed_triples_sbert.csv'))
sbert_20240927 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240927.export_goosed_triples_sbert.csv'))
sbert_20240928 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240928.export_goosed_triples_sbert.csv'))
sbert_20240929 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240929.export_goosed_triples_sbert.csv'))
sbert_20240930 = pd.read_csv(Path('/data/elugos/titlesbert_202409_FL/20240930.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202409_FL = pd.concat(
    [
        sbert_20240924,
        sbert_20240925,
        sbert_20240926,
        sbert_20240927,
        sbert_20240928,
        sbert_20240929,
        sbert_20240930,
    ],
    ignore_index=True
)

# %%
sbert_20240924_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240924.export_goosed_triples_sbert.csv'))
sbert_20240925_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240925.export_goosed_triples_sbert.csv'))
sbert_20240926_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240926.export_goosed_triples_sbert.csv'))
sbert_20240927_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240927.export_goosed_triples_sbert.csv'))
sbert_20240928_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240928.export_goosed_triples_sbert.csv'))
sbert_20240929_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240929.export_goosed_triples_sbert.csv'))
sbert_20240930_NC = pd.read_csv(Path('/data/elugos/titlesbert_202409_NC/20240930.export_goosed_triples_sbert.csv'))

# --- Concatenate into a single DataFrame ---
SBERT_202409_NC = pd.concat(
    [
        sbert_20240924_NC,
        sbert_20240925_NC,
        sbert_20240926_NC,
        sbert_20240927_NC,
        sbert_20240928_NC,
        sbert_20240929_NC,
        sbert_20240930_NC,
    ],
    ignore_index=True
)

# %%
SBERT_202409_NC.to_csv('SBERT_202409_NC.csv', index=False) 
SBERT_202409_FL.to_csv('SBERT_202409_FL.csv', index=False)
SBERT_201908.to_csv('SBERT_201908.csv', index=False) 
SBERT_202404.to_csv('SBERT_202404.csv', index=False) 
SBERT_202005.to_csv('SBERT_202005.csv', index=False) 
SBERT_202412.to_csv('SBERT_202412.csv', index=False) 
SBERT_202501.to_csv('SBERT_202501.csv', index=False) 
SBERT_202510.to_csv('SBERT_202510.csv', index=False) 
SBERT_CA.to_csv('SBERT_CA.csv', index=False) 
SBERT_FL.to_csv('SBERT_FL.csv', index=False) 
SBERT_VA.to_csv('SBERT_VA.csv', index=False) 
SBERT_NY.to_csv('SBERT_NY.csv', index=False) 
SBERT_CO.to_csv('SBERT_CO.csv', index=False)

# %%
def pairwise(df):
   df_work = df.copy(deep=True)
   # Parse embeddings
   s = df_work['embedding_json'].astype(str).str.strip()
   s = s.str.lstrip('[').str.rstrip(']')
   s = s.str.split(',')
   vecs = [np.array(list(map(float, parts)), dtype=np.float32) for parts in s]
   X = np.vstack(vecs)
   d = pairwise_distances(X,metric='cosine')
   return d

# %%
d = pairwise(SBERT_CA)

# %%
def drop_isolates_from_affinity(A):
    """
    Remove isolated nodes from an adjacency/affinity matrix.
    An isolated node is any row where all values are zero
    (including the diagonal).

    Returns:
        A_reduced: (k x k) adjacency matrix with isolates removed
        mask: boolean array of shape (n,) where True = kept node
        idx_map: array of original indices for each row in A_reduced
    """
    A = np.asarray(A)
    n = A.shape[0]

    # Identify isolates: row sum = 0 AND diag = 0
    row_sums = A.sum(axis=1)
    diag = np.diag(A)
    keep_mask = (row_sums > 0) | (diag != 0)

    # Reduce matrix
    A_reduced = A[np.ix_(keep_mask, keep_mask)]

    # Mapping: reduced index → original index
    idx_map = np.where(keep_mask)[0]

    return A_reduced, keep_mask, idx_map

# %%
def spectral_embed_from_adjacency(
    A: np.ndarray,
    n_components: int = 2,
    node_ids: Optional[Union[np.ndarray, list]] = None,
    drop_isolates: bool = False,
    make_symmetric: bool = False,
    zero_self_loops: bool = False,
    use_sparse: bool = False,
    **kwargs
) -> pd.DataFrame:
    """
    Compute a spectral embedding from an adjacency matrix and return a DataFrame
    with columns ['x','y', ...]. Works with dense or sparse input.

    Args:
        A : np.ndarray (n x n)
            Adjacency (non-negative). If not perfectly symmetric, set make_symmetric=True.
        n_components : int, default 2
            Dimensions of the embedding.
        node_ids : array-like of shape (n,), optional
            Labels to associate with rows. Defaults to range(n).
        drop_isolates : bool, default False
            If True, nodes with degree 0 are dropped from the output.
            If False, isolates are kept with NaN coordinates.
        make_symmetric : bool, default True
            If True, symmetrize A as (A + A.T) / 2.
        zero_self_loops : bool, default True
            If True, zero out the diagonal of A.
        use_sparse : bool, default True
            If True, pass a CSR matrix to sklearn (recommended for large graphs).
        **kwargs :
            Extra args passed to sklearn.manifold.SpectralEmbedding, e.g.:
            - eigen_solver={'arpack','amg','lobpcg'}
            - random_state=42
            Note: We set affinity='precomputed' internally.

    Returns:
        pd.DataFrame:
            Columns: ['node_id','x','y', ...] (or just coords if node_ids not provided).
            If drop_isolates=False, isolates have NaN for coordinates.
    """
    A = np.asarray(A)
    if A.ndim != 2 or A.shape[0] != A.shape[1]:
        raise ValueError("A must be a square (n x n) adjacency matrix.")

    n = A.shape[0]
    if node_ids is None:
        node_ids = np.arange(n)
    else:
        node_ids = np.asarray(node_ids)
        if node_ids.shape[0] != n:
            raise ValueError("node_ids must have length equal to A.shape[0].")

    # Basic hygiene on adjacency
    if make_symmetric:
        A = 0.5 * (A + A.T)
    if zero_self_loops:
        np.fill_diagonal(A, 0.0)

    # Identify isolates (degree 0)
    degrees = A.sum(axis=1)
    valid_mask = degrees > 0

    # Build the submatrix for non-isolates
    if valid_mask.any():
        A_valid = A[np.ix_(valid_mask, valid_mask)]
        if use_sparse:
            A_valid = sparse.csr_matrix(A_valid)

        # SpectralEmbedding expects an affinity matrix; adjacency is OK when using 'precomputed'
        emb = SpectralEmbedding(
            n_components=n_components,
            affinity="precomputed",
            n_jobs= -1,
            **kwargs
        )
        coords_valid = emb.fit_transform(A_valid)  # (n_valid, n_components)
    else:
        # All isolates; produce an all-NaN coordinate matrix
        coords_valid = np.empty((0, n_components))

    # Build column names: x, y, x2, x3, ...
    col_names = []
    if n_components >= 1: col_names.append("x")
    if n_components >= 2: col_names.append("y")
    for i in range(2, n_components):
        col_names.append(f"x{i}")

    # Prepare output with NaNs, then fill for non-isolates
    out_coords = np.full((n, n_components), np.nan, dtype=float)
    out_coords[valid_mask, :] = coords_valid

    # Assemble DataFrame
    df_out = pd.DataFrame(out_coords, columns=col_names)
    df_out.insert(0, "node_id", node_ids)

    if drop_isolates:
        df_out = df_out.loc[valid_mask].reset_index(drop=True)

    return df_out

# %%
s_matrix = spectral_embed_from_adjacency(
    d,
    n_components=40,
    make_symmetric=True,
    zero_self_loops=True,
    use_sparse=True,
    random_state=42
)

# %%
SBERT_CA
# Out:
#       GlobalEventID      date  source_index               subject  \
# 0         298143273  20140521           150     3 young daughters
# 1         298119883  20140521            50  9/11 Memorial Museum
# 2         298198975  20140521           328     Adaptive Insights
# 3         298240156  20140521           528     Air Force Academy
# 4         298193098  20140521           308  Alien Life Discovery
# ...             ...       ...           ...                   ...
# 1782      299078979  20140528           375                 today
# 1783      299037286  20140528           196                 vigil
# 1784      299055568  20140528           297                 water
# 1785      298999098  20140521            12                    we
# 1786      298996848  20130528             0                 women
#
#                        relation                object  \
# 0                    stabbed in                  home
# 1                      opens in                  N.Y.
# 2     Introduces CFO Council to  Share Best Practices
# 3                    accused of               assault
# 4           Could Happen Within              20 Years
# ...                         ...                   ...
# 1782                        for           legislators
# 1783                      honor      shooting victims
# 1784                  use of is             big issue
# 1785        Will meet aliens in                future
# 1786              give birth in           confinement
#
#                                              sbert_text  \
# 0                     3 young daughters stabbed in home
# 1                    9/11 Memorial Museum opens in N.Y.
# 2     Adaptive Insights Introduces CFO Council to Sh...
# 3                  Air Force Academy accused of assault
# 4     Alien Life Discovery Could Happen Within 20 Years
# ...                                                 ...
# 1782                              today for legislators
# 1783                       vigil honor shooting victims
# 1784                          water use of is big issue
# 1785                      we Will meet aliens in future
# 1786                    women give birth in confinement
#
#                                          embedding_json  \
# 0     [0.06230288743972778, -0.0957544818520546, -0....
# 1     [0.051454003900289536, -0.03214360773563385, -...
# 2     [-0.03597509488463402, -0.07527439296245575, -...
# 3     [-0.05819458141922951, 0.029577841982245445, -...
# 4     [-0.07679972797632217, 0.0418841652572155, 0.0...
# ...                                                 ...
# 1782  [-0.03329929709434509, 0.05755629017949104, 0....
# 1783  [0.039957016706466675, 0.11863356828689575, -0...
# 1784  [0.028787175193428993, 0.050198763608932495, 0...
# 1785  [-0.06675326824188232, -0.005143007729202509, ...
# 1786  [-0.03907578065991402, 0.050208449363708496, -...
#
#                                  embedding_subject_json  \
# 0     [0.016309797763824463, -0.05669090524315834, -...
# 1     [-0.0056261648423969746, 0.07737838476896286, ...
# 2     [-0.00019048819376621395, -0.02321563847362995...
# 3     [-0.040520697832107544, -0.07348322123289108, ...
# 4     [-0.07773356884717941, 0.032086942344903946, -...
# ...                                                 ...
# 1782  [-0.05599326640367508, 0.08729038387537003, -0...
# 1783  [-0.006018728017807007, 0.04381842538714409, -...
# 1784  [-0.03914299234747887, 0.05515474081039429, 0....
# 1785  [-0.10077688097953796, 0.09593737125396729, -0...
# 1786  [0.007278107572346926, -0.020804405212402344, ...
#
#                                 embedding_relation_json  \
# 0     [0.04609699547290802, 0.002789541846141219, 0....
# 1     [0.012315756641328335, -0.048136550933122635, ...
# 2     [-0.07207439094781876, -0.1301930844783783, -0...
# 3     [-0.08613000065088272, 0.07507592439651489, -0...
# 4     [-0.044993046671152115, -0.014309690333902836,...
# ...                                                 ...
# 1782  [-0.08095002919435501, 0.048514436930418015, 0...
# 1783  [-0.08905588090419769, 0.11978667229413986, 0....
# 1784  [0.04521894082427025, 0.07126026600599289, -0....
# 1785  [-0.03321806713938713, -0.032961808145046234, ...
# 1786  [-0.009457058273255825, 0.10395653545856476, -...
#
#                                   embedding_object_json
# 0     [0.04095584899187088, 0.019688230007886887, -0...
# 1     [0.029776936396956444, -0.004530746024101973, ...
# 2     [0.007986193522810936, 0.028053250163793564, -...
# 3     [-0.02088300511240959, 0.1124887689948082, 0.0...
# 4     [-0.017345115542411804, 0.08245325833559036, 0...
# ...                                                 ...
# 1782  [-0.026807822287082672, -0.004884549416601658,...
# 1783  [0.048413604497909546, 0.0659618079662323, -0....
# 1784  [0.012409343384206295, 0.10103677958250046, 0....
# 1785  [-0.10883750021457672, 0.061655234545469284, -...
# 1786  [-0.001864550868049264, 0.04266972094774246, -...
#
# [1787 rows x 11 columns]

# %%
s_matrix
# Out:
#       node_id         x         y        x2        x3        x4        x5  \
# 0           0  0.000402 -0.000173  0.000414 -0.000260  0.000074  0.000310
# 1           1 -0.000174  0.000990  0.000021 -0.000478 -0.000407  0.000209
# 2           2  0.000033  0.000410  0.000082 -0.000992 -0.000217 -0.000077
# 3           3 -0.000351  0.000946  0.001247  0.000412  0.000326  0.000829
# 4           4 -0.000261  0.000170 -0.000473 -0.000511  0.000924  0.000441
# ...       ...       ...       ...       ...       ...       ...       ...
# 1782     1782  0.002523 -0.000845 -0.001079 -0.000092 -0.000781 -0.000019
# 1783     1783  0.000347 -0.000267  0.000371 -0.000634 -0.000006 -0.000178
# 1784     1784 -0.000688 -0.000118 -0.000052  0.000778 -0.000416  0.000242
# 1785     1785  0.000606  0.000841  0.000504 -0.000663  0.000229  0.000485
# 1786     1786 -0.000077  0.001007  0.000434  0.000345 -0.000268  0.000168
#
#             x6        x7        x8  ...       x30       x31       x32  \
# 0     0.000201 -0.000198  0.000061  ... -0.000222 -0.000602  0.000719
# 1    -0.000527  0.000396 -0.000898  ... -0.000751 -0.000291  0.000350
# 2    -0.000647 -0.000261 -0.000613  ...  0.000973 -0.001230 -0.000980
# 3    -0.000064 -0.000377  0.000393  ...  0.000329  0.000603  0.000230
# 4    -0.000059  0.000254 -0.000083  ...  0.000834 -0.000039 -0.000378
# ...        ...       ...       ...  ...       ...       ...       ...
# 1782  0.000582  0.001572 -0.001617  ...  0.000377  0.000315 -0.000504
# 1783  0.000870 -0.000038  0.000282  ...  0.000129  0.000459  0.000568
# 1784 -0.000419 -0.000602  0.000308  ... -0.000727  0.000514 -0.000010
# 1785 -0.000456 -0.000748 -0.000109  ... -0.001130  0.000056 -0.000097
# 1786 -0.000287 -0.000777  0.000637  ...  0.000152  0.000291 -0.000465
#
#            x33       x34       x35       x36       x37       x38       x39
# 0    -0.000591 -0.000025  0.000119 -0.000028 -0.000563 -0.000654  0.000462
# 1     0.000591 -0.000159 -0.000049  0.000999  0.000280 -0.000111 -0.000683
# 2     0.000750 -0.000126 -0.000754 -0.000466  0.000586  0.000522 -0.000484
# 3     0.000436  0.000807 -0.000349 -0.000507  0.000566 -0.000400  0.000320
# 4    -0.000576 -0.000075 -0.000396 -0.000376 -0.000083  0.000471  0.000440
# ...        ...       ...       ...       ...       ...       ...       ...
# 1782  0.000480 -0.000020  0.000193 -0.000325  0.000571 -0.000314  0.000039
# 1783  0.000802  0.000266 -0.000436 -0.000449  0.000213  0.000100  0.000685
# 1784  0.000081  0.000544  0.000166  0.000537  0.000039  0.000067  0.000380
# 1785 -0.000287  0.000002  0.000470  0.000522 -0.000627 -0.000128 -0.000506
# 1786  0.000252 -0.000114 -0.000060  0.000332  0.000008  0.000014  0.000697
#
# [1787 rows x 41 columns]

# %%
s_matrix['GlobalEventID'] = SBERT_CA['GlobalEventID'].values

# %%
s_matrix
# Out:
#       node_id         x         y        x2        x3        x4        x5  \
# 0           0  0.000402 -0.000173  0.000414 -0.000260  0.000074  0.000310
# 1           1 -0.000174  0.000990  0.000021 -0.000478 -0.000407  0.000209
# 2           2  0.000033  0.000410  0.000082 -0.000992 -0.000217 -0.000077
# 3           3 -0.000351  0.000946  0.001247  0.000412  0.000326  0.000829
# 4           4 -0.000261  0.000170 -0.000473 -0.000511  0.000924  0.000441
# ...       ...       ...       ...       ...       ...       ...       ...
# 1782     1782  0.002523 -0.000845 -0.001079 -0.000092 -0.000781 -0.000019
# 1783     1783  0.000347 -0.000267  0.000371 -0.000634 -0.000006 -0.000178
# 1784     1784 -0.000688 -0.000118 -0.000052  0.000778 -0.000416  0.000242
# 1785     1785  0.000606  0.000841  0.000504 -0.000663  0.000229  0.000485
# 1786     1786 -0.000077  0.001007  0.000434  0.000345 -0.000268  0.000168
#
#             x6        x7        x8  ...       x31       x32       x33  \
# 0     0.000201 -0.000198  0.000061  ... -0.000602  0.000719 -0.000591
# 1    -0.000527  0.000396 -0.000898  ... -0.000291  0.000350  0.000591
# 2    -0.000647 -0.000261 -0.000613  ... -0.001230 -0.000980  0.000750
# 3    -0.000064 -0.000377  0.000393  ...  0.000603  0.000230  0.000436
# 4    -0.000059  0.000254 -0.000083  ... -0.000039 -0.000378 -0.000576
# ...        ...       ...       ...  ...       ...       ...       ...
# 1782  0.000582  0.001572 -0.001617  ...  0.000315 -0.000504  0.000480
# 1783  0.000870 -0.000038  0.000282  ...  0.000459  0.000568  0.000802
# 1784 -0.000419 -0.000602  0.000308  ...  0.000514 -0.000010  0.000081
# 1785 -0.000456 -0.000748 -0.000109  ...  0.000056 -0.000097 -0.000287
# 1786 -0.000287 -0.000777  0.000637  ...  0.000291 -0.000465  0.000252
#
#            x34       x35       x36       x37       x38       x39  \
# 0    -0.000025  0.000119 -0.000028 -0.000563 -0.000654  0.000462
# 1    -0.000159 -0.000049  0.000999  0.000280 -0.000111 -0.000683
# 2    -0.000126 -0.000754 -0.000466  0.000586  0.000522 -0.000484
# 3     0.000807 -0.000349 -0.000507  0.000566 -0.000400  0.000320
# 4    -0.000075 -0.000396 -0.000376 -0.000083  0.000471  0.000440
# ...        ...       ...       ...       ...       ...       ...
# 1782 -0.000020  0.000193 -0.000325  0.000571 -0.000314  0.000039
# 1783  0.000266 -0.000436 -0.000449  0.000213  0.000100  0.000685
# 1784  0.000544  0.000166  0.000537  0.000039  0.000067  0.000380
# 1785  0.000002  0.000470  0.000522 -0.000627 -0.000128 -0.000506
# 1786 -0.000114 -0.000060  0.000332  0.000008  0.000014  0.000697
#
#       GlobalEventID
# 0         298143273
# 1         298119883
# 2         298198975
# 3         298240156
# 4         298193098
# ...             ...
# 1782      299078979
# 1783      299037286
# 1784      299055568
# 1785      298999098
# 1786      298996848
#
# [1787 rows x 42 columns]

# %%
# Helper: pick the correct t-SNE iteration arg across sklearn versions
def _make_tsne(n_components=2, perplexity=30, random_state=42, max_iter=1000, **kwargs):
    sig = inspect.signature(TSNE.__init__)
    common = dict(n_components=n_components,
                  perplexity=perplexity,
                  learning_rate="auto",
                  init="pca",
                  random_state=random_state)
    if "max_iter" in sig.parameters:
        return TSNE(max_iter=max_iter, **common, **kwargs)
    else:
        return TSNE(n_iter=max_iter, **common, **kwargs)

def tsne_reduce(
    df: pd.DataFrame,
    feature_cols: list[str],
    perplexity: float = 30.0,
    scale: bool = True,
    max_iter: int = 1000,
    random_state: int = 42,
    **tsne_kwargs
) -> pd.DataFrame:

    # Drop bad rows for t-SNE
    X = (
        df[feature_cols]
        .replace([np.inf, -np.inf], np.nan)
        .dropna(axis=0, how="any")
    )
    keep_idx = X.index

    # Convert to NumPy + scale
    Xv = X.to_numpy(dtype=float)
    if scale:
        Xv = StandardScaler().fit_transform(Xv)

    # Adjust perplexity to dataset size
    n = Xv.shape[0]
    max_valid = max(5.0, min(50.0, (n - 1) / 3))
    perp = min(perplexity, max_valid)

    tsne = _make_tsne(
        n_components=2,
        perplexity=perp,
        random_state=random_state,
        max_iter=max_iter,
        **tsne_kwargs
    )
    Y = tsne.fit_transform(Xv)

    # -----------------------------
    # PRESERVE METADATA (IMPORTANT)
    # -----------------------------
    out = df.loc[keep_idx, ["node_id", "GlobalEventID"]].copy()

    # Add t-SNE coords
    out["tsne_x"] = Y[:, 0]
    out["tsne_y"] = Y[:, 1]

    return out

# %%
def plot_tsne(all_emb):
# 2) t-SNE on those 50 dims -> 2D
    feat_cols = ["x", "y"] + [f"x{i}" for i in range(2, 40)]  # total 50 columns
    tsne_df = tsne_reduce(all_emb, feature_cols=feat_cols, perplexity=30.0, max_iter=1000, random_state=42)

    tsne_df["node_index"] = range(len(tsne_df))  # matrix row number

    merged_df = tsne_df.merge(
    global_db[["GlobalEventID", "EventCode", "state", "title"]],
    on="GlobalEventID",
    how="left"
)

    merged_df["CAMEO_num"] = merged_df["EventCode"].astype(str).str.extract(r"(\d+)$")
    cameo_lookup = {v: k for k, v in cameo_codes.items()}
    merged_df["CAMEO_desc"] = merged_df["CAMEO_num"].map(cameo_lookup)
    merged_df["CAMEO_label"] = merged_df["CAMEO_num"] + ": " + merged_df["CAMEO_desc"].fillna("Unknown")

    merged_df["CAMEO_num"] = merged_df["EventCode"].astype(str).str.extract(r"(\d+)$")
    cameo_lookup = {v: k for k, v in cameo_codes.items()}
    merged_df["CAMEO_desc"] = merged_df["CAMEO_num"].map(cameo_lookup)
    merged_df["CAMEO_label"] = merged_df["CAMEO_num"] + ": " + merged_df["CAMEO_desc"].fillna("Unknown")

    # --- Plot ---
    fig = px.scatter(
        merged_df,
        x="tsne_x",
        y="tsne_y",
        color="state",           # color by event code             # shape by state (independent)
        hover_data={
            "GlobalEventID": True,
            "EventCode": True,
            "CAMEO_label": True,
            "title": True,
            "state": True,
            "tsne_x": False,
            "tsne_y": False,
        },
        title="t-SNE Projection — Color: CAMEO Code",
        template="plotly_white"
    )

    # --- Fix combined legend issue ---
    # Separate legends by creating independent traces per symbol (state)
    for trace in fig.data:
        trace.showlegend = True if trace.marker.symbol else False

    fig.update_traces(marker=dict(size=6, opacity=0.8))
    fig.update_layout(
        legend_title_text="",
        legend=dict(groupclick="toggleitem", itemsizing="constant")
    )

    fig.show()

# %%
plot_15 = plot_tsne(s_matrix)
# Out:
#       node_id  GlobalEventID    tsne_x    tsne_y
# 0           0      298143273  0.520196  4.633271
# 1           1      298119883 -0.528743 -0.712617
# 2           2      298198975  2.143076  2.017684
# 3           3      298240156  3.309922 -9.498179
# 4           4      298193098 -6.975087  0.294615
# ...       ...            ...       ...       ...
# 1782     1782      299078979  3.950818  6.960744
# 1783     1783      299037286 -2.341668  1.388516
# 1784     1784      299055568 -3.018109 -2.321085
# 1785     1785      298999098  0.105814  1.731048
# 1786     1786      298996848 -1.419263 -1.436844
#
# [1787 rows x 4 columns]

# %%
s_matrix
# Out:
#       node_id         x         y        x2        x3        x4        x5  \
# 0           0  0.000402 -0.000173  0.000414 -0.000260  0.000074  0.000310
# 1           1 -0.000174  0.000990  0.000021 -0.000478 -0.000407  0.000209
# 2           2  0.000033  0.000410  0.000082 -0.000992 -0.000217 -0.000077
# 3           3 -0.000351  0.000946  0.001247  0.000412  0.000326  0.000829
# 4           4 -0.000261  0.000170 -0.000473 -0.000511  0.000924  0.000441
# ...       ...       ...       ...       ...       ...       ...       ...
# 1782     1782  0.002523 -0.000845 -0.001079 -0.000092 -0.000781 -0.000019
# 1783     1783  0.000347 -0.000267  0.000371 -0.000634 -0.000006 -0.000178
# 1784     1784 -0.000688 -0.000118 -0.000052  0.000778 -0.000416  0.000242
# 1785     1785  0.000606  0.000841  0.000504 -0.000663  0.000229  0.000485
# 1786     1786 -0.000077  0.001007  0.000434  0.000345 -0.000268  0.000168
#
#             x6        x7        x8  ...       x31       x32       x33  \
# 0     0.000201 -0.000198  0.000061  ... -0.000602  0.000719 -0.000591
# 1    -0.000527  0.000396 -0.000898  ... -0.000291  0.000350  0.000591
# 2    -0.000647 -0.000261 -0.000613  ... -0.001230 -0.000980  0.000750
# 3    -0.000064 -0.000377  0.000393  ...  0.000603  0.000230  0.000436
# 4    -0.000059  0.000254 -0.000083  ... -0.000039 -0.000378 -0.000576
# ...        ...       ...       ...  ...       ...       ...       ...
# 1782  0.000582  0.001572 -0.001617  ...  0.000315 -0.000504  0.000480
# 1783  0.000870 -0.000038  0.000282  ...  0.000459  0.000568  0.000802
# 1784 -0.000419 -0.000602  0.000308  ...  0.000514 -0.000010  0.000081
# 1785 -0.000456 -0.000748 -0.000109  ...  0.000056 -0.000097 -0.000287
# 1786 -0.000287 -0.000777  0.000637  ...  0.000291 -0.000465  0.000252
#
#            x34       x35       x36       x37       x38       x39  \
# 0    -0.000025  0.000119 -0.000028 -0.000563 -0.000654  0.000462
# 1    -0.000159 -0.000049  0.000999  0.000280 -0.000111 -0.000683
# 2    -0.000126 -0.000754 -0.000466  0.000586  0.000522 -0.000484
# 3     0.000807 -0.000349 -0.000507  0.000566 -0.000400  0.000320
# 4    -0.000075 -0.000396 -0.000376 -0.000083  0.000471  0.000440
# ...        ...       ...       ...       ...       ...       ...
# 1782 -0.000020  0.000193 -0.000325  0.000571 -0.000314  0.000039
# 1783  0.000266 -0.000436 -0.000449  0.000213  0.000100  0.000685
# 1784  0.000544  0.000166  0.000537  0.000039  0.000067  0.000380
# 1785  0.000002  0.000470  0.000522 -0.000627 -0.000128 -0.000506
# 1786 -0.000114 -0.000060  0.000332  0.000008  0.000014  0.000697
#
#       GlobalEventID
# 0         298143273
# 1         298119883
# 2         298198975
# 3         298240156
# 4         298193098
# ...             ...
# 1782      299078979
# 1783      299037286
# 1784      299055568
# 1785      298999098
# 1786      298996848
#
# [1787 rows x 42 columns]
